# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\VIVEK PRATAP\Desktop\python project VS\ML_Projects\Netflix_data_analysis\netflix_movies (1).csv")

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
data.shape    # To checkc the no. of row and columns
# Out:
# (8807, 12)

# %%
data.size
# Out:
# 105684

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.dtypes    # to check the data type
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.info()    # To show index columns, data-type of each columns, memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.duplicated()    # to check the duplicate value
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
data[data.duplicated()]  # To check row and detect the duplicate row
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data.drop_duplicates(inplace=True)      # To remove the Duplicate row permanently

# %%
data[data.duplicated()]    # To again checck row
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data.shape
# Out:
# (8807, 12)

# %% [markdown]
# # Taska 2 > Is there any null values in present columns? show Heat-map

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()    # To show the count of null values
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 7       False  False  False     False  False    False       False
# 8       False  False  False     False  False    False       False
# 9       False  False  False     False  False    False       False
# 12      False  False  False     False  False    False       False
# 24      False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8801    False  False  False     False  False    False       False
# 8802    False  False  False     False  False    False       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 7            False   False     False      False        False
# ...

# %%
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())         #Using heat-map to show null values count
# Out:
# <Axes: >

# %%
data.isin(['vivek'])       # To check the perticular column if ("") if data present or not
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 7       False  False  False     False  False    False       False
# 8       False  False  False     False  False    False       False
# 9       False  False  False     False  False    False       False
# 12      False  False  False     False  False    False       False
# 24      False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8801    False  False  False     False  False    False       False
# 8802    False  False  False     False  False    False       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 7            False   False     False      False        False
# ...

# %%
data[data['country'].isin(['Spark'])]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, data_N]
# Index: []

# %%
data.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
data.shape
# Out:
# (5332, 12)

# %%
data[data['title'].str.contains('Sankofa')]    # To check the the particular column this data present or not
# Out:
#   show_id   type    title      director  \
# 7      s8  Movie  Sankofa  Haile Gerima
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
#
#    release_year rating duration  \
# 7          1993  TV-MA  125 min
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
#
#                                          description
# 7  On a photo shoot in Ghana, an American model s...

# %% [markdown]
# Q1> In which year heighst number of tv shows & movies were released?

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data['data_N'] = pd.to_datetime(data['date_added'], format='%B %d, %Y', errors='coerce')

# %%
data['data_N'].dt.year.value_counts().sort_index()
# Out:
# data_N
# 2008.0       1
# 2009.0       2
# 2010.0       1
# 2011.0      13
# 2012.0       3
# 2013.0       7
# 2014.0      14
# 2015.0      50
# 2016.0     202
# 2017.0     722
# 2018.0    1100
# 2019.0    1264
# 2020.0    1194
# 2021.0     755
# Name: count, dtype: int64

# %%
data['data_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='data_N'>

# %% [markdown]
# Q2 > How ManyMovies & TV show in dataset

# %%
data.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description     data_N
# ...

# %%
data.groupby('type').type.count()
# Out:
# type
# Movie      5185
# TV Show     147
# Name: type, dtype: int64

# %%
sns.countplot(data['type'])
# Out:
# <Axes: xlabel='count', ylabel='type'>

# %% [markdown]
# Q3 > Show all movies that were released in year 2000

# %%
data.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
(data['date_added'], format=='%Y-%m-%d')
# Out:
# (7       September 24, 2021
#  8       September 24, 2021
#  9       September 24, 2021
#  12      September 23, 2021
#  24      September 21, 2021
#                 ...
#  8801         March 9, 2016
#  8802     November 20, 2019
#  8804      November 1, 2019
#  8805      January 11, 2020
#  8806         March 2, 2019
#  Name: date_added, Length: 5332, dtype: object,
#  False)

# %%
(data['release_year'], format=='%Y-%m-%d')
# Out:
# (7       1993
#  8       2021
#  9       2021
#  12      2021
#  24      1998
#          ...
#  8801    2015
#  8802    2007
#  8804    2009
#  8805    2006
#  8806    2015
#  Name: release_year, Length: 5332, dtype: int64,
#  False)

# %%
movies_df = data2[data2["type"] == "Movie"]
movies_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 movies_df = data2[data2["type"] == "Movie"]
#       2 movies_df
#
# TypeError: tuple indices must be integers or slices, not str

# %%
# Filter for movies only
movies_df = data[data["type"] == "Movie"]
movies_df
# Out:
#      show_id   type         title             director  \
# 7         s8  Movie       Sankofa         Haile Gerima
# 9        s10  Movie  The Starling       Theodore Melfi
# 12       s13  Movie  Je Suis Karl  Christian Schwochow
# 24       s25  Movie         Jeans           S. Shankar
# 27       s28  Movie     Grown Ups         Dennis Dugan
# ...      ...    ...           ...                  ...
# 8801   s8802  Movie       Zinzana      Majid Al Ansari
# 8802   s8803  Movie        Zodiac        David Fincher
# 8804   s8805  Movie    Zombieland      Ruben Fleischer
# 8805   s8806  Movie          Zoom         Peter Hewitt
# 8806   s8807  Movie        Zubaan          Mozez Singh
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...

# %%
# Group by release year and count the number of movies released each year
release_counts = movies_df["release_year"].value_counts()
release_counts
# Out:
# release_year
# 2017    640
# 2018    632
# 2016    567
# 2019    495
# 2020    409
#        ...
# 1946      1
# 1961      1
# 1942      1
# 1947      1
# 1944      1
# Name: count, Length: 72, dtype: int64

# %%
# Get the year with the maximum number of movies released
most_released_year = release_counts.idxmax()
most_released_count = release_counts.max()

print(f"The year with the most movies released is {most_released_year} with {most_released_count} movies.")
# Out:
# The year with the most movies released is 2017 with 640 movies.

# %%
sns.countplot(data['type'])
# Out:
# <Axes: xlabel='count', ylabel='type'>

# %%
data['type'].isin(['TV Show'])
# Out:
# 7       False
# 8        True
# 9       False
# 12      False
# 24      False
#         ...
# 8801    False
# 8802    False
# 8804    False
# 8805    False
# 8806    False
# Name: type, Length: 5332, dtype: bool

# %%
data[data['type'].str.contains('TV Show')]
# Out:
#      show_id     type                                             title  \
# 8         s9  TV Show                     The Great British Baking Show
# 198     s199  TV Show              King of Boys: The Return of the King
# 273     s274  TV Show                                     Gone for Good
# 276     s277  TV Show                                           Valeria
# 297     s298  TV Show                                          Navarasa
# ...      ...      ...                                               ...
# 8172   s8173  TV Show             Th Eena Meena Deeka Chase Comedy Show
# 8214   s8215  TV Show  The Blue Planet: A Natural History of the Oceans
# 8293   s8294  TV Show                                          The Fear
# 8302   s8303  TV Show                                          The Five
# 8599   s8600  TV Show                                   Toast of London
#
#                                                director  \
# ...

# %%
data['type'].isin(['TV Show'])
# Out:
# 7       False
# 8        True
# 9       False
# 12      False
# 24      False
#         ...
# 8801    False
# 8802    False
# 8804    False
# 8805    False
# 8806    False
# Name: type, Length: 5332, dtype: bool

# %% [markdown]
# Q > Shows only the title of all TV shows that were released in india only

# %%
data.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description     data_N
# ...

# %%
data=data[(data['type']=='TV Show') & (data['country']=='United Kingdom')]

# %%
data.shape
# Out:
# (5332, 13)

# %%
data.size
# Out:
# 69316

# %%
data1=data[(data['type']=='TV Show') & (data['country']=='United Kingdom')]

# %%
data1.shape
# Out:
# (19, 13)

# %% [markdown]
# Q > Show the top director, who gave the heighest number of TV Shows to Netflix?

# %%
data['director'].value_counts().head()
# Out:
# director
# Alastair Fothergill    2
# Andy Devonshire        1
# Simon Frederick        1
# Mark Tonderai          1
# Michael Samuels        1
# Name: count, dtype: int64
